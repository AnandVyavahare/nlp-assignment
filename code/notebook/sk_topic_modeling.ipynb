# %%
#Basic Python Libraries
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
import re
import time
#Natural Language Processing
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
#Scikit-Learn (Machine Learning Library for Python)
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
#Evaluation Metrics
from sklearn.metrics import accuracy_score,precision_score,recall_score,confusion_matrix,roc_curve,classification_report
from scikitplot.metrics import plot_confusion_matrix
import spacy
from sklearn.decomposition import LatentDirichletAllocation

# %%
dev = pd.read_csv('../input/meld-dataset/MELD-RAW/MELD.Raw/dev_sent_emo.csv')
train = pd.read_csv('../input/meld-dataset/MELD-RAW/MELD.Raw/train/train_sent_emo.csv')
test = pd.read_csv('../input/meld-dataset/MELD-RAW/MELD.Raw/test_sent_emo.csv')

# %%
#dev.head()
#train.head()
test.head()
# Out:
#    Sr No.                                          Utterance Speaker  \
# 0       1  Why do all youre coffee mugs have numbers on ...    Mark
# 1       2  Oh. Thats so Monica can keep track. That way ...  Rachel
# 2       3                                       Y'know what?  Rachel
# 3      19                     Come on, Lydia, you can do it.    Joey
# 4      20                                              Push!    Joey
#
#     Emotion Sentiment  Dialogue_ID  Utterance_ID  Season  Episode  \
# 0  surprise  positive            0             0       3       19
# 1     anger  negative            0             1       3       19
# 2   neutral   neutral            0             2       3       19
# 3   neutral   neutral            1             0       1       23
# 4       joy  positive            1             1       1       23
#
#       StartTime       EndTime
# 0  00:14:38,127  00:14:40,378
# 1  00:14:40,629  00:14:47,385
# 2  00:14:56,353  00:14:57,520
# 3   0:10:44,769   0:10:46,146
# 4   0:10:46,146   0:10:46,833

# %%
train_dev = pd.concat([train,dev])
train_dev
# Out:
#       Sr No.                                          Utterance  \
# 0          1  also I was the point person on my companys tr...
# 1          2                   You mustve had your hands full.
# 2          3                            That I did. That I did.
# 3          4      So lets talk a little bit about your duties.
# 4          5                             My duties?  All right.
# ...      ...                                                ...
# 1104    1174                                                No.
# 1105    1175       What? Oh my God! Im gonna miss you so much!
# 1106    1176                                Im gonna miss you!
# 1107    1177                     I mean its the end of an era!
# 1108    1178                                            I know!
#
#               Speaker   Emotion Sentiment  Dialogue_ID  Utterance_ID  Season  \
# 0            Chandler   neutral   neutral            0             0       8
# 1     The Interviewer   neutral   neutral            0             1       8
# 2            Chandler   neutral   neutral            0             2       8
# 3     The Interviewer   neutral   neutral            0             3       8
# 4            Chandler  surprise  positive            0             4       8
# ...               ...       ...       ...          ...           ...     ...
# 1104           Monica   sadness  negative          113             9       6
# 1105           Rachel   sadness  negative          113            10       6
# 1106           Monica   sadness  negative          113            11       6
# 1107           Rachel   sadness  negative          113            12       6
# 1108           Monica   sadness  negative          113            13       6
#
#       Episode     StartTime       EndTime
# 0          21  00:16:16,059  00:16:21,731
# 1          21  00:16:21,940  00:16:23,442
# 2          21  00:16:23,442  00:16:26,389
# 3          21  00:16:26,820  00:16:29,572
# 4          21  00:16:34,452  00:16:40,917
# ...       ...           ...           ...
# 1104        2  00:19:28,792  00:19:29,876
# 1105        2  00:19:33,213  00:19:35,965
# 1106        2  00:19:36,175  00:19:37,967
# 1107        2  00:19:39,094  00:19:40,928
# 1108        2  00:19:41,138  00:19:42,638
#
# [11098 rows x 11 columns]

# %%
train_dev.reset_index(inplace=True,drop=True)

# %%
sent = train_dev[['Utterance','Sentiment']]

# %%
def custom_encoder(df):
    df.replace(to_replace ="positive", value = 1, inplace=True)
    df.replace(to_replace ="neutral", value = 0, inplace=True)
    df.replace(to_replace ="negative", value = -1, inplace=True)

# %%
custom_encoder(sent['Sentiment'])
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
#Creating an object of WordNetLemmatizer
lm = WordNetLemmatizer()

# %%
def data_preprocessing(text_col):
    corpus = []
    for row in text_col:
        new_row = re.sub('[^a-zA-Z]',' ',str(row)).lower().split()
        new_row = [lm.lemmatize(word) for word in new_row if word not in set(stopwords.words('english'))]
        corpus.append(' '.join(str(x) for x in new_row))
    return corpus

# %%
transformed = data_preprocessing(sent['Utterance'])

# %%
#transformed

# %%
tr_df = pd.DataFrame(zip(transformed,sent['Sentiment']), columns= ['Utterance','Sentiment'])

# %%
def get_idx(df):   
    indexes = []
    for i,dialogue in enumerate(df):
        if len(dialogue) == 0:
            empty = df.index
            #print(empty)
            indexes.append(i)
    return indexes

# %%
empty_idx = get_idx(tr_df['Utterance'])

# %%
clean_df = tr_df.drop(empty_idx)
clean_df.reset_index()
# Out:
#        index                                          Utterance  Sentiment
# 0          0  also point person company transition kl gr system          0
# 1          1                                     must hand full          0
# 2          3                           let talk little bit duty          0
# 3          4                                         duty right          1
# 4          5                    heading whole division lot duty          0
# ...      ...                                                ...        ...
# 10535  11092                   mean gonna live together anymore         -1
# 10536  11094                             oh god gonna miss much         -1
# 10537  11095                                         gonna miss         -1
# 10538  11096                                       mean end era         -1
# 10539  11097                                               know         -1
#
# [10540 rows x 3 columns]

# %%
text = clean_df['Utterance'].to_list()

# %%
text
# Out:
# ['also point person company transition kl gr system',
#  'must hand full',
#  'let talk little bit duty',
#  'duty right',
#  'heading whole division lot duty',
#  'see',
#  'perhaps people dump certain amount',
#  'good know',
#  'go detail',
#  'beg',
#  'right definite answer monday think say confidence fit well',
#  'really',
#  'absolutely relax',
#  'waitress went last month',
#  'know forget',
#  'talking',
#  'actually know',
#  'ok',
#  'right well',
#  'yeah sure',
#  'hey mon',
#  'hey hey hey wanna hear something suck',
#  'ever',
#  'chris say closing bar',
#  'way',
#  'yeah apparently turning kinda coffee place',
#  'coffee gonna hang',
#  'got',
#  'get beer',
#  'hey pick roommate',
#  'betcha',
#  'italian guy',
#  'um mm yeah right',
#  'oh god oh god poor monica',
#  'wrote poem',
#  'look vessel empty nothing inside',
#  'touched seem emptier still',
#  'think monica empty empty vase',
#  'oh totally oh god oh seemed happy',
#  'done',
#  'hey',
#  'hi',
#  'ah know building paper route',
#  'oh',
#  'hi',
#  'hi',
#  'go',
#  'oh well woman interviewed pretty tough know thank god mark coached started talking fall line got happy shut',
#  'proud',
#  'listen ah sorry crazy jealous like lot',
#  'know',
#  'yeah',
#  'yeah',
#  'ameri',
#  'ameri ccan',
#  'ameri know',
#  'everybody',
#  'good job joe well done top notch',
#  'liked really liked',
#  'oh ho ho yeah',
#  'part exactly',
#  'whole thing go',
#  'oh give specific',
#  'love specific specific best part',
#  'hey scene kangaroo like part',
#  'surprised see kangaroo world war epic',
#  'fell asleep',
#  'kangaroo',
#  'take suggestion',
#  'coming buddy',
#  'see later',
#  'go',
#  'sorry',
#  'sorry',
#  'look',
#  'guy fell asleep',
#  'fell asleep',
#  'mad',
#  'call ambulance',
#  'okay look think tell rachel messed dessert',
#  'everybody thanksgiving truth day',
#  'yes dying wish ring',
#  'see buried ring spirit going wander nether world eternity',
#  'okay enough honey',
#  'know let see ring',
#  'great okay',
#  'right',
#  'thank thank thank',
#  'oh know usual teaching aerobics partying way much',
#  'oh case wondering leg new james bond poster',
#  'hold moment another call love',
#  'know',
#  'back',
#  'gonna get together',
#  'um absolutely uh bout tomorrow afternoon know uh central perk village say five ish',
#  'great see',
#  'ok ok phone finally paid',
#  'even though good bob impression thinkin see tomorow probably gonna realize hey bob',
#  'hoping bob show seek comfort open arm wry stranger next table',
#  'oh god pure evil',
#  'ok pure evil horny alone done',
#  'nobody',
#  'nobody respect bucket',
#  'believe people put',
#  'look',
#  'okay look like garbage',
#  'wedding',
#  'right know really late let go let go let go',
#  'fine watch video get back',
#  'go phoebe go phobo phewbedo phaybobo',
#  'thank',
#  'thank',
#  'right let go bye pheebs',
#  'bye pheebs',
#  'london baby',
#  'oh need hug bring anything',
#  'hey',
#  'hey estelle lined bunch audition tomorrow health insurance back time',
#  'great toilet right',
#  'wrong',
#  'nothing',
#  'well got blinding pain stomach lifting weight uh passed uh able stand since',
#  'um think anything serious',
#  'sound like hernia go doctor',
#  'way kay look go doctor anything gonna thing sticking stomach',
#  'hernia',
#  'start working damn',
#  'love place guy',
#  'uh eighteenth century indian artifact calcutta',
#  'oh wow dinosaur',
#  'much',
#  'well well sum fun look young',
#  'okay',
#  'enough key apartment',
#  'really',
#  'really',
#  'think fast',
#  'get',
#  'ross talk minute',
#  'yes please going',
#  'uh well joey broke',
#  'oh god wh happened',
#  'joey great guy different mean speech kept laughing homo erectus',
#  'knew',
#  'anyway uh think best',
#  'hey ok',
#  'guess',
#  'hum another reason thought time end joey',
#  'started realize feeling someone else',
#  'ok geller last day conference know happens keynote speaker',
#  'oh professor clerk kind middle conversation',
#  'yeah guy throw pool later',
#  'could throw',
#  'ok gentleman',
#  'please',
#  'little old',
#  'mean scientist right',
#  'academic',
#  'importantly catch u first',
#  'go go go',
#  'go go go',
#  'oh yeah everybody want hat',
#  'oy',
#  'sand',
#  'oh yeah bob said might flood damage',
#  'yeah either really big cat',
#  'okay see blind guy right gonna bash head later',
#  'oh umm big scene coming big scene coming',
#  'said big lima bean bubbling would understand difference',
#  'rach',
#  'oh boy watch scary',
#  'diaper commercial',
#  'oh yeah well know baby responsibility ahhh',
#  'pizza delivery',
#  'get get',
#  'hi',
#  'hi',
#  'hey wanna get something eat uh wanna see long throw ball back forth huh',
#  'uhh ball thing',
#  'yeah',
#  'hey ross great could go two straight hour without dropping',
#  'uhh',
#  'okay',
#  'uh oh',
#  'pee rachel bathroom',
#  'man think gonna make',
#  'know switch hand okay',
#  'hey',
#  'hey',
#  'go erin',
#  'oh unbelievable best time',
#  'yay oh mad u anymore',
#  'guy totally right',
#  'much better first time went',
#  'know',
#  'awkward really nervous',
#  'sleep together',
#  'yeah really calm',
#  'much common',
#  'love sandwich sport although met fan much issue ever kid well',
#  'oh god listen talkin kid oh joey oh please get married',
#  'okay',
#  'cannot sleep public place',
#  'would look peaceful',
#  'oh hi',
#  'okay know nodded',
#  'going',
#  'got sleep last night',
#  'grandmother new boyfriend kind insecure bed',
#  'oh deaf',
#  'constantly like reassure good time',
#  'idea loud',
#  'well want stay rachel tonight',
#  'thanks',
#  'ew something exploded',
#  'water breaking calm',
#  'water breaking mean water breaking',
#  'breathe breathe breathe',
#  'insane mean joey going kill actually going kill dead',
#  'okay think thought',
#  'know one',
#  'mean unbelievable',
#  'mean gina',
#  'one gina',
#  'dark big hair airplane earring',
#  'dina',
#  'see tell one either dwha',
#  'know thought see saturday funny',
#  'look honey mark fashion okay like friend share stuff',
#  'guy would never want go lecture',
#  'pa haa would love go',
#  'really',
#  'yeah hey clothes even pick',
#  'mean know could fashion monger',
#  'okay honey would love go',
#  'wear nervous',
#  'know hey incredible huh',
#  'know amazing mean totally nailed beautiful',
#  'thank listen thanks lot tribbiani oh god look time gotta catch bus ball',
#  'oh well okay good luck',
#  'yeah',
#  'unless wanna practice foxtrot tango',
#  'ahh thanks see think ready dance girl',
#  'okay',
#  'yeah',
#  'go get em treeger',
#  'right hey ahh wanna come marge girlfriend',
#  'really',
#  'yeah could dance real good size',
#  'good',
#  'oh god nerve wracking',
#  'well unfortunately get many callback',
#  'good sign asked u hang around audition',
#  'know',
#  'okay uh narrowed raymond ben kyle joey rest thank much',
#  'yes knew bye bye long later',
#  'oh great might actually get play ben dad',
#  'yeah',
#  'actually happen',
#  'yeah different look putting raymond kyle ben',
#  'either two two',
#  'man gonna kinda weird',
#  'yeah',
#  'gonna like best friend gonna weird',
#  'okay come get married get something old something new something borrowed something blue',
#  'okay right right right okay okay something something blue new',
#  'please',
#  'kidding',
#  'hurt three huge men gave guy bloody nose mean proud really',
#  'wonderful amazing',
#  'think got concussion',
#  'serious thank',
#  'welcome sorry hurt',
#  'worth pain know know',
#  'wow mike thing interesting know gonna happen phoebe david',
#  'want hint huh',
#  'ok sensing kind word play pink barely controlled glee',
#  'david going propose phoebe',
#  'chandler talked',
#  'supposed give people advice',
#  'made sort inappropriate joke',
#  'going week phoebe completely hung mike',
#  'say david heart broken hard recover phoebe end alone',
#  'man',
#  'oh want',
#  'father paul stevens dad ross geller',
#  'great meet paul',
#  'usually prefer elizabeth boyfriend address mr stevens',
#  'course course mr stevens',
#  'ross problem',
#  'eh wh excuse',
#  'get girlfriend age',
#  'funny umm funny',
#  'okay',
#  'see',
#  'umm think give umm one chance change mind',
#  'okay',
#  'okay give one chance change mind got one minute',
#  'daddy',
#  'oh well tv yet',
#  'well wall yet',
#  'okay fine bring tape huh',
#  'umm matt lauer clothes maybe one cleaned yet',
#  'ooooohh',
#  'oh yeah sure sudden hand problem anymore',
#  'oh boy scout could camped',
#  'ooo',
#  'uma thurman',
#  'oh',
#  'actress',
#  'thanks rach',
#  'gonna',
#  'tell',
#  'tell',
#  'moral obligation friend woman think feminist issue',
#  'guy',
#  'guy',
#  'oh yeah tell',
#  'feminist issue went',
#  'gonna hate',
#  'yeah well',
#  'marry',
#  'big night wanted wish good luck',
#  'yeah yeah ring',
#  'yeah right pocket pheebs',
#  'oh oop',
#  'okay guy get want surprise gonna know',
#  'yeah yeah guy get',
#  'hi guy',
#  'beautiful',
#  'oh thank going',
#  'really excited charity event go',
#  'okay umm ross',
#  'really warm going taking sweater',
#  'letting know',
#  'yep hilarious',
#  'sorry done done',
#  'know last night embarrassing',
#  'really mean seen naked hundred time',
#  'uh huh first rest building',
#  'okay right true know embarrass easily',
#  'totally get embarrassed',
#  'ross think secure person',
#  'yeah',
#  'hey lady care much want okay',
#  'believe',
#  'rode bike',
#  'never thought able',
#  'thank ross',
#  'oh hey thank thank one faced fear ultimately overcame',
#  'hey guy',
#  'mean two mean lucky one good',
#  'thanks man',
#  'gotta go check something',
#  'baby',
#  'total wuss',
#  'okay lot option number prototype try',
#  'wow look great',
#  'yeah okay one mushroom cap umm one made bologna',
#  'toothpick',
#  'kissed another woman',
#  'call even',
#  'okay',
#  'well gonna go get water',
#  'wait stole people wedding',
#  'took hotel lobby',
#  'yeah think charge dirty movie bag mashuga nut got another think coming',
#  'hey',
#  'sweater',
#  'looking like month',
#  'oh god',
#  'oh god',
#  'happy supposed vic happy',
#  'well tell supposed',
#  'huh',
#  'sure hell figure',
#  'talk nothin',
#  'look nothin',
#  'nothing',
#  'tasty really starting feel like guy history nice',
#  'question scene',
#  'yes',
#  'well understand adrienne attracted victor',
#  'peel onion first good looking',
#  'yeah',
#  'think character gonna need little bit reason',
#  'oh hey one',
#  'ah say script',
#  'know ah know character like either mean say script bitch',
#  'say script',
#  'mine',
#  'yeah gotta tell girl tape rookie mistake',
#  'know great video camera',
#  'greg jenny',
#  'still wanna call em wanna call em',
#  'let call em',
#  'yeah ask brought friend souvenir',
#  'hello eighth street deli',
#  'hey hang get food poisoning talkin place',
#  'uh sorry wrong number',
#  'go',
#  'hello deli',
#  'right sandwich',
#  'think number right',
#  'oh come',
#  'gotta go miss love getting real late',
#  'hey listen made appointment dr bazida excuse know',
#  'name ronni pet mortician',
#  'sure long',
#  'remember little kid used take navy yard show big ship',
#  'since',
#  'six year',
#  'wanted put nice memory head know always terrible guy',
#  'joe',
#  'ever love',
#  'know',
#  'burning tomato',
#  'one talk',
#  'joe dad love big time worst part two different woman',
#  'oh man please tell one em',
#  'course course one em matter',
#  'everything gonna right okay dick',
#  'hello guru saj whoa supposed duck right cause otherwise waaay league',
#  'hey rach work',
#  'oh great although sit chair',
#  'way ross dropped box stuff',
#  'oh well guess one coming',
#  'gonna throw probably bunch shampoo',
#  'something wrong',
#  'nothing',
#  'said thing bringing mesozoic era st century',
#  'yeah',
#  'yeah',
#  'dude sorry said',
#  'right ridiculous name',
#  'bad',
#  'yes first name',
#  'bing',
#  'apartment back',
#  'ace high jack queen king ace',
#  'ace low ace two three four',
#  'know ooh ooh look ah ha',
#  'right cut let pick pick',
#  'okay',
#  'come apartment come apartment oh know queen high',
#  'uh huh high worked king',
#  'yeah baby',
#  'pick pick',
#  'know',
#  'ticket please courtside baby',
#  'seriously good game though good game mad get apartment back',
#  'know think brought enough stuff forget pack baby anvil',
#  'gonna worth',
#  'known fact woman love baby right',
#  'woman love guy love baby',
#  'whole sensitive thing',
#  'quick aim pack babe',
#  'maybe one break away',
#  'wait get got one hard left',
#  'right gimme baby',
#  'got',
#  'oh seriously want',
#  'hello',
#  'well think immodest',
#  'wanna smell',
#  'oh yeah got great baby smell get whiff head',
#  'tell tell',
#  'well great guy',
#  'bye',
#  'well really',
#  'mean technically rule anything frowned upon',
#  'especially professor ran last night judgey von holierthanthou',
#  'well ross careful want get reputation know professor mcnailshisstudents',
#  'yeah',
#  'well ross seems pretty clear',
#  'mean important',
#  'people think feel huh',
#  'ross gotta follow heart',
#  'joey sweet',
#  'hey',
#  'hey hey hey go dana reason leave block time open say thursday',
#  'hey relax need time going dinner tonight',
#  'going',
#  'going',
#  'uh dana keystone college',
#  'oh yeah uh',
#  'dana caplin',
#  'joey even know',
#  'ah whatever',
#  'morning hey favorite genius little robot buddy',
#  'touch',
#  'okay',
#  'right',
#  'umm right wayne level',
#  'keep hearing rumor might get fired',
#  'okay even actor coming read part',
#  'come man got give second chance',
#  'mean love love little guy',
#  'ah ah',
#  'okay want touch right',
#  'go',
#  'okay',
#  'stupid',
#  'believe',
#  'god',
#  'hey doin',
#  'hey',
#  'hi look um happened earlier',
#  'hey well completely understand stressed',
#  'gonna give chance apologise',
#  'letting throw office',
#  'yeah well excuse wanting girlfriend anniversary boy as',
#  'told time',
#  'yeah well never time mean feel like even girlfriend anymore rachel',
#  'wh ross want',
#  'want want quit job feel like girlfriend',
#  'know',
#  'ooh tell something',
#  'tell',
#  'okay easier tell something could tell',
#  'well sure perfect world promised tell swore like god',
#  'okay ross rachel',
#  'joey',
#  'chandler sock keep bed',
#  'let come back later',
#  'hi',
#  'richard',
#  'actually complement chef',
#  'ohh oh okay hate people come back complement chef',
#  'like nothing better',
#  'well great seeing night',
#  'oh good see come tell',
#  'came tell something else came tell still love',
#  'one pregnant woman time please want okay',
#  'forcing marry bobby gonna make happen',
#  'maybe well well uh kind music numb nut oh forget',
#  'joey scared death',
#  'really think gonna need help',
#  'bobby gonna whole time',
#  'bet answer earlier question straight gangster rap',
#  'look rachel told much easier made',
#  'cause cause baby sister',
#  'big brother',
#  'mean favorite guy whole world',
#  'even scared tell mom dad',
#  'scared telling',
#  'well scared right',
#  'joey stand thought baby mad',
#  'want uncle',
#  'baby gonna uncle joey',
#  'course gonna uncle joey',
#  'gonna right mean even married baby gonna loved u',
#  'right uncle',
#  'okay bobby come let little moment',
#  'come',
#  'seriously wrong',
#  'really nice time tonight',
#  'really glad monica asked u',
#  'love ask uh sister visiting think asleep couch',
#  'sister sister asleep couch ohhh saw',
#  'oh hey great rachel sister krista krista rachel',
#  'hi',
#  'nice meet wish told company fix',
#  'like would help',
#  'bad',
#  'dead gonna get',
#  'uh nice meeting',
#  'oh god victoria secret model something something goodacre',
#  'hi mom jill',
#  'right jill jill goodacre oh god trapped atm vestibule jill goodacre',
#  'yeah fine stuck bank atm vestibule',
#  'jill say vestibule going vestibule',
#  'fine alone know guy',
#  'oh guy guy hey jill saw guy last night yes',
#  'seeing anybody right',
#  'og ee op asking mean gay asking',
#  'gay',
#  'personal shopping like walk around snooty rich people tell buy',
#  'uh huh',
#  'sound great',
#  'hey',
#  'umm excuse switched apartment eat food anymore gravy train ended',
#  'gravy',
#  'big apartment deal people coming time',
#  'fridge got stocked okay department',
#  'think left donut',
#  'conclusion line go happy',
#  'great job team',
#  'tomorrow',
#  'phil',
#  'nice job',
#  'stevens',
#  'way go',
#  'joel burg maniac',
#  'love ya',
#  'bing',
#  'oh excuse forgot briefcase know accident',
#  'course',
#  'forgot something else ya bastard',
#  'well',
#  'feeling left anything ya',
#  'ridiculous',
#  'everybody else got one want one',
#  'ye ye yeah yes',
#  'get',
#  'hey bob',
#  'hey pal toby today',
#  'see ask',
#  'toby',
#  'yeah',
#  'oh know',
#  'semi first name basis',
#  'think adding team',
#  'bob ooh working u everyday yeah know take',
#  'really love six',
#  'eleven almost twice hard',
#  'hey guess got wedding',
#  'freakish thin date hanger head',
#  'rachel hooked tux tux batman tux',
#  'right made expressly val kilmer worn hit film batman film',
#  'wear wearing famous tux james bond tux',
#  'wear make mine le special',
#  'sorry like idea say thinking yeah',
#  'well still problem',
#  'yeah',
#  'well trying find someone perform wedding either boring annoying know stop staring lady',
#  'oo one u',
#  'phoebe getting',
#  'uh real thing anyone get ordained internet perform like wedding stuff',
#  'call',
#  'idea',
#  'guy thank much neither marrying u',
#  'calling mean anything anymore',
#  'going legitimate member clergy say legitimate mean gay control saliva',
#  'see see big passion future',
#  'really',
#  'oh ross great playfully rub head get',
#  'supposed good thing forget',
#  'listen monica know okay know sleep like month got like dot ink one sofa cushion',
#  'well coulda turned cushion',
#  'yeah would except big spaghetti stain side',
#  'okay talking need live land people spill',
#  'spill sink',
#  'aw honey fault know love want u friend keep living see happening',
#  'love',
#  'aww good',
#  'said',
#  'wondering cushion',
#  'oh god serious',
#  'uh huh',
#  'would love live ross great thank',
#  'well glad could know help',
#  'ross ross idea mean',
#  'mean mean gonna homeless',
#  'saved',
#  'hero',
#  'hero uh know well right',
#  'oh go tell monica wonderful brother',
#  'oh please gonna say thing ya',
#  'tell exact thing happened roommate denise',
#  'moved guy secretly married said love really blew',
#  'dammit hire girl okay everybody ready',
#  'uh listen wanna thank great opportunity',
#  'lose robe',
#  'great',
#  'well gonna get another espresso get another latte',
#  'still working mine',
#  'yeah really hard',
#  'oh yeah hug looked pretty brutal',
#  'ok',
#  'wow ah pretty nice',
#  'pretty nice',
#  'pardon roommate wanted marry',
#  'buck would willing trade got canoe',
#  'know really think need canoe',
#  'gotta take canoe',
#  'right take entertainment center get home throw canoe away',
#  'throwing away built canoe',
#  'good',
#  'pheebs',
#  'yeah',
#  'okay guess wait hi need one fake ticket yemen',
#  'one ticket yemen',
#  'oh need pretend ticket',
#  'sorry sir understand',
#  'would give kid wanted ticket play',
#  'travelling child',
#  'right know gonna think handing credit card really gonna hand library card',
#  'okay last time',
#  'chick chick chick chick',
#  'chick chick everywhere chick chick chickeeeen',
#  'hey',
#  'hey',
#  'well yeah think',
#  'know tell ever went back quickly',
#  'well anyway got go change ah meeting cast drink',
#  'excuse',
#  'okay good go go vince',
#  'yeah jason really sensitive',
#  'well sensitive important pick',
#  'yeah',
#  'oh sure go sissy',
#  'jason sissy',
#  'oh meant chandler',
#  'hi',
#  'uh apparently people familiar europe story',
#  'yeah',
#  'listen whole uh came thing really matter',
#  'mean think would happened either way',
#  'mean initiated know would',
#  'amazing night',
#  'amazing night',
#  'think looked amazing',
#  'name yet',
#  'yet',
#  'fine call baby girl green',
#  'oh baby girl geller green',
#  'hello baby girl',
#  'ah ha nowhere run',
#  'like sitting gonna',
#  'rachel got first',
#  'ross',
#  'danger',
#  'oh god jumping woman',
#  'right worry',
#  'oh look gonna leave stain',
#  'rach hey fine joey',
#  'really',
#  'yeah look',
#  'never lived like',
#  'know',
#  'right waste mean still food',
#  'hey joey bed olivia lost virginity',
#  'know one extra sure hey listen rach thanks coming watch scene',
#  'oh please honey fact want support oh god christian sander',
#  'also',
#  'oh head done pretty gay stuff',
#  'well christmas party santa definitely gay stuff',
#  'ok got promise never ever tell ross told',
#  'planning birthday party',
#  'oh god love',
#  'better act surprised',
#  'surprise party',
#  'surprise party',
#  'oh stop joey already told',
#  'well tell',
#  'hey look ross thing',
#  'typical always last one know everything',
#  'tell stuff',
#  'yuh huh',
#  'last one know chandler got bitten peacock zoo',
#  'last one know crush joey moving',
#  'look like second last',
#  'chandler still gotten rsvp dad',
#  'oh right umm maybe send invitation',
#  'chandler father wedding',
#  'even know man okay close seen year',
#  'well gonna find even asked',
#  'like run circle',
#  'hang guy star drag show vega',
#  'ooh think wanna trade circle',
#  'nobody gonna staring bride father groom wearing back le dress',
#  'long wearing white dress veil care',
#  'okay think need shopping',
#  'hello',
#  'ya doin',
#  'hell',
#  'guess believe said kurt douglas huh',
#  'rachel get see u',
#  'yeah groom cannot see bride',
#  'gonna marry chandler',
#  'okay guy relax doooo',
#  'gotta go',
#  'oh wait joshua joshua yeah well oughta',
#  'sorry late left late',
#  'okay',
#  'pheebs book',
#  'thought said read high school',
#  'well yeah remembered started pep rally top pyramid anyway umm book',
#  'excuse bum one',
#  'know actually okay okay okay funny',
#  'thought smoke',
#  'oh thought guy meant marijuana cigarette know',
#  'know mean like dubbies',
#  'actually thought wow guy crazy',
#  'actually smoke regular one time',
#  'get high',
#  'oh',
#  'kidding',
#  'oh',
#  'oh sure ok',
#  'yeah',
#  'still hurt',
#  'yeah',
#  'neat idea clothes match gonna',
#  'hi',
#  'hey go',
#  'excellent',
#  'ripped couple apart kept piece',
#  'beautiful story hey fine way',
#  'know right',
#  'good pheebs',
#  'ok',
#  'okay guy microphone mean',
#  'suck know stay night went stupid sleep clinic tired',
#  'hi',
#  'yeah rach think handling really well',
#  'handling',
#  'mean handling',
#  'nothing handle',
#  'maybe would problem joshua',
#  'know gonna get married anyway',
#  'come',
#  'rushed thing fast ridiculous',
#  'somewhere along way one gonna realise done call whole thing',
#  'telling ya gonna dancing wedding dancing',
#  'hell',
#  'actually thought would make feel better give stuff use another two month',
#  'suck',
#  'right next present',
#  'right nuclear holocaust last man earth would go',
#  'enhh',
#  'got canned good',
#  'hey guy take look check baby dug hole',
#  'excellent hole joe',
#  'oh hole',
#  'ow ow',
#  'drinking',
#  'oh must said left',
#  'said exactly',
#  'enjoyed occasional drink ing binge',
#  'oh god ohh leaving horrible person',
#  'wait wait wait wait wait wait wait wait',
#  'gonna get sensitive',
#  'want lose',
#  'create position',
#  'make assistant buyer department',
#  'say thing like',
#  'office raise effective tomorrow',
#  'need expense account',
#  'done',
#  'assistant',
#  'sophie get',
#  'monica gonna proud got u date two unbelievably cute nurse',
#  'oh',
#  'male nurse',
#  'head',
#  'anyway want take u saturday night say',
#  'umm umm umm think',
#  'talking',
#  'one telling get ross move',
#  'moving moving',
#  'come give one good reason wanna go',
#  'umm give',
#  'harder sound',
#  'okay coming also told still get go cafeteria',
#  'yep always room',
#  'joey make',
#  'oh easy yeah anything watch uh grandma chicken salad',
#  'hello monica',
#  'yeah',
#  'oh',
#  'okay yes right right',
#  'thank',
#  'okay let bring',
#  'wait honey honey throw throw',
#  'go',
#  'almost hit face',
#  'well magician open beer cheek right',
#  'hey',
#  'hey',
#  'know really glad decided sleep together wedding',
#  'oh boy',
#  'know thinking big fight uh broke hour',
#  'yeah',
#  'technically could sex think bossy domineering',
#  'wedding sloppy immature',
#  'come',
#  'okay wait cousin cassie guest room supposed lunch',
#  'well get rid obsessive shrill',
#  'shrill wedding back',
#  'thought heard voice must chandler',
#  'hi nice meet',
#  'nice meet',
#  'ready go',
#  'yeah',
#  'chandler',
#  'right',
#  'th th third nipple',
#  'run mill third nipple',
#  'take',
#  'slice baby right',
#  'take shirt let see dealing',
#  'showing run mill slice right third nipple',
#  'well third nipple',
#  'first as',
#  'well',
#  'wait minute hold johnson come moment',
#  'hamilton',
#  'good rear thing bring',
#  'umm great wine',
#  'france europe western europe know umm year ago actually backpacking across western europe',
#  'really',
#  'uh hmm wait get better um yeah barcelona',
#  'studied year barcelona',
#  'anyway umm um hiking',
#  'love hiking',
#  'oh great hiking along foothill mount tibidaybo',
#  'congratulation two even know got married',
#  'oh',
#  'um uh baby together uh uh',
#  'uh well umm place know excited',
#  'oh well shut',
#  'tell',
#  'uh oh feel another one coming',
#  'let go ross',
#  'yeah well know chi chi',
#  'promise',
#  'chandler promise good',
#  'come filter tipped little buddy stay outside',
#  'hey pheebs',
#  'dear m buffay',
#  'thank calling attention error',
#  'credited account five hundred dollar',
#  'sorry inconvenience hope accept',
#  'oh god honey meant together copy',
#  'honey',
#  'hey great advice joey thing',
#  'yeah work problem',
#  'oh perfect mean really felt like friend',
#  'problem tell',
#  'oh important point really think everything gonna okay',
#  'okay got one wanna put panty',
#  'thanks mom',
#  'ha ha baby ha ha ha',
#  'good good',
#  'really really enjoyed exotic',
#  'well checked message joshua call',
#  'mean think worried showing club',
#  'ugh know make much worse ross happy vermont',
#  'come look',
#  'get sec another round daiquiri',
#  'remember virgin please',
#  'oh let leave without getting name carpet guy',
#  'ahh come know know think gonna go home call kathy',
#  'well think help',
#  'test',
#  'couple hour gonna get really drunk wanna call kathy guy gonna stop',
#  'gonna get drunk gonna wanna call janice',
#  'ohhh',
#  'think somebody need another lap dance',
#  'right definitely taste nutmeg',
#  'well difference professional layman',
#  'arrogance',
#  'hey',
#  'hey sailing',
#  'wow thanks',
#  'joe',
#  'yeah',
#  'uh lot sex right',
#  'today lot',
#  'well reason asking kind eh uh unable mean really wanted',
#  'huh hmm incident',
#  'worry man happens',
#  'happened',
#  'yeah',
#  'well',
#  'anyway',
#  'sup sup dude',
#  'take whatever want please hurt',
#  'playing little',
#  'yes scale dumbest person look definitely',
#  'come man really old',
#  'young man child okay go get changed everybody ready please oh please keep underwear',
#  'knew',
#  'okay well ross really',
#  'look home want able come go whenever want',
#  'okay find someplace else rest appointment know big deal',
#  'big deal want naked greasy stranger apartment want kick back puzzle beer cold beer',
#  'okay look gonna hurt right',
#  'always bring',
#  'wanna leave alone',
#  'alright',
#  'first fight morning',
#  'think working late',
#  'said thing mean threw faeces',
#  'know gonna work late could look',
#  'oh great',
#  'okay make sure seems like see okay like favour',
#  'okay asks going lie',
#  'check',
#  'say place go rent video museum',
#  'almost good',
#  'better go museum underwear',
#  'oh ho bet british version gooooood',
#  'uh may help',
#  'yeah talked phone lady got stuck racecar bed',
#  'look like told nothing signed monica velula geller',
#  'right jester man look wanna see king',
#  'nobody see king',
#  ...]

# %%
#clean_df['Sentiment'].value_counts()

# %% [markdown]
# ## Topic Modeling with LDA in Sklearn

# %%
tfidf = TfidfVectorizer(use_idf=True, norm= 'l1')
traindata = tfidf.fit_transform(text)

# %%
#len(tfidf.get_feature_names())
type(traindata)
# Out:
# scipy.sparse.csr.csr_matrix

# %% [markdown]
# ### Creating the vocab to represent all the corpus

# %%
vocab_tfidf = tfidf.get_feature_names()
len(vocab_tfidf)
# Out:
# 4928

# %% [markdown]
# ### Implementing LDA

# %%
# Instantiating LDA
lda_model = LatentDirichletAllocation(n_components=6, max_iter = 20, random_state = 42, batch_size= 500)

# Fitting and transforming model on our tfidf vectorizer to get topics
x_topics = lda_model.fit_transform(traindata)

# Checking topic distribution
topic_words = lda_model.components_

# %%
topic_words.shape
# Out:
# (6, 4928)

# %%
topic_words
# Out:
# array([[0.16672491, 0.58265694, 0.16667513, ..., 0.34705817, 0.83804244,
#         0.27151967],
#        [0.16671725, 0.16667686, 0.1666736 , ..., 0.16668495, 0.16675655,
#         0.16670535],
#        [0.1667268 , 0.16667668, 0.64975365, ..., 0.16669075, 0.16669473,
#         0.16669798],
#        [0.17397972, 0.16667415, 0.16667527, ..., 0.16701279, 0.62054375,
#         0.16683166],
#        [0.29279431, 0.16667604, 0.16667465, ..., 0.1666878 , 0.16851304,
#         0.16696818],
#        [0.16698611, 0.16667531, 0.16667475, ..., 0.16668589, 0.16669356,
#         0.166696  ]])

# %%
# defining the number of words to print in every topic
n_top_words = 6

for i, topic_dist in enumerate(topic_words):
    #sorting the indices so in the topic_words array
    sorted_topic_dist = np.argsort(topic_dist)
    
    #Fetching the actual words for the sorted indices above
    actual_topic_words = np.array(vocab_tfidf)[sorted_topic_dist]
    
    #Showing top n_top_words per topic
    n_top_topic_words = actual_topic_words[:-n_top_words:-1]
    print ("Topic", str(i+1), n_top_topic_words)
# Out:
# Topic 1 ['huh' 'mean' 'sure' 'chandler' 'thanks']
# Topic 2 ['yeah' 'okay' 'oh' 'know' 'god']
# Topic 3 ['great' 'thank' 'wait' 'love' 'ohh']
# Topic 4 ['sorry' 'come' 'yes' 'tell' 'think']
# Topic 5 ['joey' 'good' 'going' 'phoebe' 'ok']
# Topic 6 ['hey' 'really' 'right' 'hi' 'see']

# %%
actual_topic_words
# Out:
# array(['laugh', 'dock', 'awesome', ..., 'right', 'really', 'hey'],
#       dtype='<U25')

# %%
# To view what topics are assigned to the douments:

doc_topic = lda_model.transform(traindata)  

# iterating over ever value till the end value
for n in range(20):
    
    # argmax() gives maximum index value
    topic_doc = doc_topic[n].argmax()
    
    # document is n+1  
    print ("Document", n+1, " -- Topic:" ,topic_doc)
# Out:
# Document 1  -- Topic: 4
# Document 2  -- Topic: 2
# Document 3  -- Topic: 3
# Document 4  -- Topic: 3
# Document 5  -- Topic: 3
# Document 6  -- Topic: 5
# Document 7  -- Topic: 4
# Document 8  -- Topic: 4
# Document 9  -- Topic: 2
# Document 10  -- Topic: 4
# Document 11  -- Topic: 0
# Document 12  -- Topic: 5
# Document 13  -- Topic: 3
# Document 14  -- Topic: 2
# Document 15  -- Topic: 2
# Document 16  -- Topic: 0
# Document 17  -- Topic: 3
# Document 18  -- Topic: 4
# Document 19  -- Topic: 5
# Document 20  -- Topic: 0

# %%
for i in range(20):
    print("Document", i+1,text[i])
# Out:
# Document 1 also point person company transition kl gr system
# Document 2 must hand full
# Document 3 let talk little bit duty
# Document 4 duty right
# Document 5 heading whole division lot duty
# Document 6 see
# Document 7 perhaps people dump certain amount
# Document 8 good know
# Document 9 go detail
# Document 10 beg
# Document 11 right definite answer monday think say confidence fit well
# Document 12 really
# Document 13 absolutely relax
# Document 14 waitress went last month
# Document 15 know forget
# Document 16 talking
# Document 17 actually know
# Document 18 ok
# Document 19 right well
# Document 20 yeah sure
